# %%
## Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats
from numpy.core.fromnumeric import mean

# %%
df_medical = pd.read_csv("Data/Data_Medial.csv")
df_medical.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
## Creating first graph to explore VitD_levels feature

## Calculating Stats
col = "VitD_levels"
feature = df_medical[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
std_plus = mean + std
std_minus = mean - std 

## Creating Graph
fig, ax = plt.subplots(figsize = (20, 10))
ax = sns.histplot(feature, ax = ax, stat = "probability", kde = True) 
ax.axvline(mean, color = "red", label = f'Mean = {mean}');
ax.axvline(median, color = "green", label = f'Median = {median}')
ax.axvline(std_plus, color = "black", label = f'std + 1 = {std_plus}');
ax.axvline(std_minus, color = "black", label = f'std - 1 = {std_minus}')
ax.axvspan(std_plus, std_minus, color = "yellow", zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
## Finding kurtosis
kurt = stats.kurtosis(df_medical["VitD_levels"], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# ## Graph One Analysis:
# ---
# 1. Continuous
# 2. Normal - no skew
# 3. Mesokurtic with a score of 3.013

# %%
## Creating second graph to explore Doc_visits feature

## Calculating Stats
col = "Doc_visits"
feature = df_medical[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
std_plus = mean + std
std_minus = mean - std 

## Creating Graph
fig, ax = plt.subplots(figsize = (20, 10))
ax = sns.histplot(feature, ax = ax, kde = True) 
ax.axvline(mean, color = "red", label = f'Mean = {mean}');
ax.axvline(median, color = "green", label = f'Median = {median}')
ax.axvline(std_plus, color = "black", label = f'std + 1 = {std_plus}');
ax.axvline(std_minus, color = "black", label = f'std - 1 = {std_minus}')
ax.axvspan(std_plus, std_minus, color = "yellow", zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
## Finding kurtosis
kurt = stats.kurtosis(df_medical["Doc_visits"], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# ## Graph Two Analysis:
# ---
# 1. Discrete
# 2. Normal - no skew
# 3. Mesokurtic with a score of 2.992

# %%
## Creating third graph to explore TotalCharge feature

## Calculating Stats
col = "TotalCharge"
feature = df_medical[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
std_plus = mean + std
std_minus = mean - std 

## Creating Graph
fig, ax = plt.subplots(figsize = (20, 10))
ax = sns.histplot(feature, ax = ax, kde = True) 
ax.axvline(mean, color = "red", label = f'Mean = {mean}');
ax.axvline(median, color = "green", label = f'Median = {median}')
ax.axvline(std_plus, color = "black", label = f'std + 1 = {std_plus}');
ax.axvline(std_minus, color = "black", label = f'std - 1 = {std_minus}')
ax.axvspan(std_plus, std_minus, color = "yellow", zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
## Finding kurtosis
kurt = stats.kurtosis(df_medical["TotalCharge"], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# ## Graph Three Analysis:
# ---
# 1. Continuous
# 2. Negative Skew
# 3. Platykurtic with a score of 3.265
